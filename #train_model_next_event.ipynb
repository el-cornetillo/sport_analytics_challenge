# %%
import pandas as pd
import time
import re
import json
import numpy as np
from random import shuffle

import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras import backend as K
from keras.utils import to_categorical
from keras.callbacks import Callback
from keras.layers import Bidirectional, GRU
from keras.layers import Layer
from keras.layers import Reshape, Flatten
from keras.layers import GlobalAveragePooling1D, add, Lambda, subtract
from keras import initializers, regularizers, constraints
from keras.models import Model
from keras.backend.tensorflow_backend import _to_tensor
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Input, Embedding, Dropout, Dense, TimeDistributed
from keras.layers import concatenate, BatchNormalization
from keras.models import model_from_json
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

from collections import Counter, defaultdict

sn.set(font_scale=1.4)#for label size


t0 = time.time()
df = pd.read_csv('./next_event_dataset.csv')
print("Fully loaded in {:02d}m{:02d}s".format(*divmod(int(time.time() - t0), 60)))
# Out:
# Using TensorFlow backend.
# Fully loaded in 00m01s

# %%
d = defaultdict(int)

x = df.events.str.split(' / ')
for elt in x:
    for w in elt:
        d[w] += 1

d = dict(d)

EMBEDDING_FILE = "./embeddings/light_vectors_50dim_15epochs.txt"
EMBEDDING_DIM = 50

def get_embedding():
    embeddings_index = {}
    f = open(EMBEDDING_FILE)
    for line in f:
        values = line.split()
        word = values[0]
        if len(values) == EMBEDDING_DIM + 1 and word in all_words:
            coefs = np.asarray(values[1:], dtype="float32")
            embeddings_index[word] = coefs
    f.close()
    return embeddings_index

all_words = set(d.keys())
print('All words : ', len(all_words))

embeddings_index = get_embedding()

docs = sum([[key] * value for key, value in d.items()], [])
shuffle(docs)

tokenizer = Tokenizer(lower=False, filters="", split="--")
tokenizer.fit_on_texts(docs)

word_index = tokenizer.word_index
rv_word_index = {v: k for k, v in word_index.items()}

nb_words = len(word_index) + 1
embedding_matrix = np.random.rand(nb_words, EMBEDDING_DIM)

for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
    else:
        print('not_found: %s' % word)
        
print('Embedding mat : ', embedding_matrix.shape)
# Out:
# All words :  40
# Embedding mat :  (41, 50)

# %%
events = [[word_index[w] for w in elt.split(" / ")] for elt in df.events]
events = np.array(events, dtype='int32')

pos = [[[float(xx), float(yy)] for xx, yy in zip(x.split(' / '), y.split(' / '))] for x, y in zip(df['xs'], df['ys'])]
pos = np.array(pos)


refs = [[int(r) for r in elt.split(' / ')] for elt in df.refs]
refs = np.array(refs)


deltas = [[int(d) for d in elt.split(' / ')] for elt in df.deltas]
deltas = np.array(deltas)


next_pos = [[float(x), float(y)] for x, y in zip(df.next_x, df.next_y)]
next_pos = np.array(next_pos)


switch = df.team_changed.values.astype(int)[..., None]

# %%
n_units = 50

def build_model():
    events_input = Input(shape=(10,))
    pos_input = Input(shape=(10, 2,))
    refs_input = Input(shape=(10,))
    deltas_input = Input(shape=(10,))

    embed_layer = Embedding(input_dim=embedding_matrix.shape[0],
                            output_dim=embedding_matrix.shape[1],
                            weights=[embedding_matrix],
                            input_length=None,  # sentence size vary from batch to batch
                            trainable=True
                            )

    events_wv = embed_layer(events_input)
    past = concatenate([events_wv,
                       pos_input,
                       Reshape((10, 1))(refs_input),
                       #Reshape((10, 1))(at_home_input),
                       Reshape((10, 1))(deltas_input)])
    bidir_gru = Bidirectional(GRU(units=n_units,
                                         activation='tanh', 
                                         dropout=0.0,
                                         recurrent_dropout=0.0,
                                         implementation=1,
                                         return_sequences=False,
                                         reset_after=True,
                                         recurrent_activation='sigmoid'),
                                     merge_mode='concat', weights=None)

    future = bidir_gru(past)
    fmap = Dense(256, activation='relu')(future)
    fmap = Dropout(0.2)(fmap)
    
    pred_switch = Dense(1, activation='sigmoid', name = "switch")(fmap)
    pred_pos = Dense(2, activation='linear', name = "pos")(fmap)

    model = Model([events_input, pos_input, refs_input, deltas_input], [pred_switch, pred_pos])
    
    return model

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True)
model_count = 1

for train, test in skf.split(np.zeros(len(df)), df.next_event.tolist()):
    print("MODEL:", model_count)

    events_train = events[train]
    pos_train = pos[train]
    refs_train = refs[train]
    deltas_train = deltas[train]
    next_pos_train = next_pos[train]
    switch_train = switch[train]

    events_test = events[test]
    pos_test = pos[test]
    refs_test = refs[test]
    deltas_test = deltas[test]
    next_pos_test = next_pos[test]
    switch_test = switch[test]
    
    
    K.clear_session()

    model = build_model()

    model.compile(loss={"switch": 'binary_crossentropy',
                        'pos': 'mean_squared_error'},
                  optimizer="adam",
                  metrics={"switch": 'acc', 'pos': 'mse'})

    early_stopping = EarlyStopping(monitor="val_pos_mean_squared_error", patience=2)
    best_model_path = "best_model" + str(model_count) + ".h5"
    model_checkpoint = ModelCheckpoint(best_model_path, monitor = "val_pos_mean_squared_error",
                                       mode="min", save_best_only=True, save_weights_only=True)
    
    callback_list = [early_stopping, model_checkpoint]
    
    hist = model.fit([events_train, pos_train, refs_train, deltas_train], [switch_train, next_pos_train],
                     validation_data=([events_test, pos_test, refs_test, deltas_test], [
                                      switch_test, next_pos_test]),
                     epochs=100,
                     callbacks=callback_list,
                     verbose=1,
                     batch_size=1048
                    )

    model.load_weights(best_model_path)
    
    model_json = model.to_json()
    with open("next_event_model_%d.json" % model_count, "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("next_event_model_%d.h5" % model_count)
    print("Saved model to disk")

    model_count += 1
# Out:
# MODEL: 1
# Train on 256614 samples, validate on 64176 samples
# Epoch 1/100
# 256614/256614 [==============================] - 9s 36us/step - loss: 699.0452 - switch_loss: 0.7931 - pos_loss: 698.2521 - switch_acc: 0.5776 - pos_mean_squared_error: 698.2521 - val_loss: 264.5395 - val_switch_loss: 0.6244 - val_pos_loss: 263.9150 - val_switch_acc: 0.6552 - val_pos_mean_squared_error: 263.9150
# Epoch 2/100
# 256614/256614 [==============================] - 9s 35us/step - loss: 264.2831 - switch_loss: 0.6361 - pos_loss: 263.6470 - switch_acc: 0.6499 - pos_mean_squared_error: 263.6470 - val_loss: 247.9947 - val_switch_loss: 0.6065 - val_pos_loss: 247.3882 - val_switch_acc: 0.6670 - val_pos_mean_squared_error: 247.3882
# Epoch 3/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 251.9352 - switch_loss: 0.6157 - pos_loss: 251.3195 - switch_acc: 0.6644 - pos_mean_squared_error: 251.3195 - val_loss: 239.6996 - val_switch_loss: 0.6033 - val_pos_loss: 239.0963 - val_switch_acc: 0.6703 - val_pos_mean_squared_error: 239.0963
# Epoch 4/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 244.6051 - switch_loss: 0.6114 - pos_loss: 243.9937 - switch_acc: 0.6663 - pos_mean_squared_error: 243.9937 - val_loss: 234.4782 - val_switch_loss: 0.6010 - val_pos_loss: 233.8772 - val_switch_acc: 0.6719 - val_pos_mean_squared_error: 233.8772
# Epoch 5/100
# 256614/256614 [==============================] - 8s 33us/step - loss: 239.7865 - switch_loss: 0.6081 - pos_loss: 239.1784 - switch_acc: 0.6665 - pos_mean_squared_error: 239.1784 - val_loss: 230.3348 - val_switch_loss: 0.5977 - val_pos_loss: 229.7371 - val_switch_acc: 0.6774 - val_pos_mean_squared_error: 229.7371
# Epoch 6/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 235.9679 - switch_loss: 0.6056 - pos_loss: 235.3623 - switch_acc: 0.6690 - pos_mean_squared_error: 235.3623 - val_loss: 228.0611 - val_switch_loss: 0.5927 - val_pos_loss: 227.4684 - val_switch_acc: 0.6781 - val_pos_mean_squared_error: 227.4684
# Epoch 7/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 232.7381 - switch_loss: 0.6066 - pos_loss: 232.1314 - switch_acc: 0.6699 - pos_mean_squared_error: 232.1314 - val_loss: 224.8871 - val_switch_loss: 0.5901 - val_pos_loss: 224.2970 - val_switch_acc: 0.6867 - val_pos_mean_squared_error: 224.2970
# Epoch 8/100
# 256614/256614 [==============================] - 9s 35us/step - loss: 230.2040 - switch_loss: 0.6046 - pos_loss: 229.5994 - switch_acc: 0.6723 - pos_mean_squared_error: 229.5994 - val_loss: 224.1812 - val_switch_loss: 0.5911 - val_pos_loss: 223.5901 - val_switch_acc: 0.6837 - val_pos_mean_squared_error: 223.5901
# Epoch 9/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 228.7216 - switch_loss: 0.6023 - pos_loss: 228.1193 - switch_acc: 0.6754 - pos_mean_squared_error: 228.1193 - val_loss: 222.6491 - val_switch_loss: 0.5878 - val_pos_loss: 222.0613 - val_switch_acc: 0.6869 - val_pos_mean_squared_error: 222.0613
# Epoch 10/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 227.1634 - switch_loss: 0.6017 - pos_loss: 226.5617 - switch_acc: 0.6760 - pos_mean_squared_error: 226.5617 - val_loss: 221.2728 - val_switch_loss: 0.5882 - val_pos_loss: 220.6846 - val_switch_acc: 0.6942 - val_pos_mean_squared_error: 220.6846
# Epoch 11/100
# 256614/256614 [==============================] - 9s 34us/step - loss: 226.2733 - switch_loss: 0.6005 - pos_loss: 225.6727 - switch_acc: 0.6781 - pos_mean_squared_error: 225.6727 - val_loss: 219.6170 - val_switch_loss: 0.5839 - val_pos_loss: 219.0331 - val_switch_acc: 0.6909 - val_pos_mean_squared_error: 219.0331
# Epoch 12/100
# 256614/256614 [==============================] - 9s 33us/step - loss: 225.1343 - switch_loss: 0.5998 - pos_loss: 224.5345 - switch_acc: 0.6791 - pos_mean_squared_error: 224.5345 - val_loss: 220.0117 - val_switch_loss: 0.5847 - val_pos_loss: 219.4270 - val_switch_acc: 0.6934 - val_pos_mean_squared_error: 219.4270
# Epoch 13/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 224.1039 - switch_loss: 0.5983 - pos_loss: 223.5056 - switch_acc: 0.6816 - pos_mean_squared_error: 223.5056 - val_loss: 218.5722 - val_switch_loss: 0.5801 - val_pos_loss: 217.9921 - val_switch_acc: 0.6983 - val_pos_mean_squared_error: 217.9921
# Epoch 14/100
# 256614/256614 [==============================] - 8s 31us/step - loss: 222.9525 - switch_loss: 0.5969 - pos_loss: 222.3556 - switch_acc: 0.6832 - pos_mean_squared_error: 222.3556 - val_loss: 218.1790 - val_switch_loss: 0.5778 - val_pos_loss: 217.6011 - val_switch_acc: 0.7005 - val_pos_mean_squared_error: 217.6011
# Epoch 15/100
# 256614/256614 [==============================] - 8s 31us/step - loss: 222.4768 - switch_loss: 0.5944 - pos_loss: 221.8824 - switch_acc: 0.6867 - pos_mean_squared_error: 221.8824 - val_loss: 217.4008 - val_switch_loss: 0.5751 - val_pos_loss: 216.8257 - val_switch_acc: 0.6977 - val_pos_mean_squared_error: 216.8257
# Epoch 16/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 221.6688 - switch_loss: 0.5891 - pos_loss: 221.0797 - switch_acc: 0.6928 - pos_mean_squared_error: 221.0797 - val_loss: 217.4581 - val_switch_loss: 0.5677 - val_pos_loss: 216.8904 - val_switch_acc: 0.7238 - val_pos_mean_squared_error: 216.8904
# Epoch 17/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 221.2712 - switch_loss: 0.5835 - pos_loss: 220.6877 - switch_acc: 0.7003 - pos_mean_squared_error: 220.6877 - val_loss: 215.6256 - val_switch_loss: 0.5641 - val_pos_loss: 215.0615 - val_switch_acc: 0.7267 - val_pos_mean_squared_error: 215.0615
# Epoch 18/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 220.7291 - switch_loss: 0.5770 - pos_loss: 220.1521 - switch_acc: 0.7074 - pos_mean_squared_error: 220.1521 - val_loss: 214.9874 - val_switch_loss: 0.5558 - val_pos_loss: 214.4315 - val_switch_acc: 0.7268 - val_pos_mean_squared_error: 214.4315
# Epoch 19/100
# 256614/256614 [==============================] - 8s 32us/step - loss: 219.6067 - switch_loss: 0.5728 - pos_loss: 219.0339 - switch_acc: 0.7134 - pos_mean_squared_error: 219.0339 - val_loss: 215.6593 - val_switch_loss: 0.5523 - val_pos_loss: 215.1071 - val_switch_acc: 0.7281 - val_pos_mean_squared_error: 215.1071
# Epoch 20/100
# 256614/256614 [==============================] - 9s 34us/step - loss: 219.4252 - switch_loss: 0.5705 - pos_loss: 218.8547 - switch_acc: 0.7159 - pos_mean_squared_error: 218.8547 - val_loss: 215.9866 - val_switch_loss: 0.5498 - val_pos_loss: 215.4367 - val_switch_acc: 0.7345 - val_pos_mean_squared_error: 215.4367
# Saved model to disk
# MODEL: 2
# Train on 256622 samples, validate on 64168 samples
# Epoch 1/100
# 256622/256622 [==============================] - 10s 39us/step - loss: 690.1979 - switch_loss: 0.8028 - pos_loss: 689.3951 - switch_acc: 0.5679 - pos_mean_squared_error: 689.3951 - val_loss: 260.5530 - val_switch_loss: 0.6433 - val_pos_loss: 259.9098 - val_switch_acc: 0.6361 - val_pos_mean_squared_error: 259.9098
# Epoch 2/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 262.9277 - switch_loss: 0.6393 - pos_loss: 262.2884 - switch_acc: 0.6463 - pos_mean_squared_error: 262.2884 - val_loss: 245.4228 - val_switch_loss: 0.6118 - val_pos_loss: 244.8110 - val_switch_acc: 0.6751 - val_pos_mean_squared_error: 244.8110
# Epoch 3/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 250.9813 - switch_loss: 0.6173 - pos_loss: 250.3640 - switch_acc: 0.6642 - pos_mean_squared_error: 250.3640 - val_loss: 237.1036 - val_switch_loss: 0.6063 - val_pos_loss: 236.4973 - val_switch_acc: 0.6715 - val_pos_mean_squared_error: 236.4973
# Epoch 4/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 243.3017 - switch_loss: 0.6139 - pos_loss: 242.6879 - switch_acc: 0.6640 - pos_mean_squared_error: 242.6879 - val_loss: 230.8591 - val_switch_loss: 0.6047 - val_pos_loss: 230.2544 - val_switch_acc: 0.6765 - val_pos_mean_squared_error: 230.2544
# Epoch 5/100
# 256622/256622 [==============================] - 8s 32us/step - loss: 238.4023 - switch_loss: 0.6119 - pos_loss: 237.7904 - switch_acc: 0.6653 - pos_mean_squared_error: 237.7904 - val_loss: 226.5010 - val_switch_loss: 0.6000 - val_pos_loss: 225.9010 - val_switch_acc: 0.6719 - val_pos_mean_squared_error: 225.9010
# Epoch 6/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 234.7357 - switch_loss: 0.6116 - pos_loss: 234.1241 - switch_acc: 0.6653 - pos_mean_squared_error: 234.1241 - val_loss: 224.3317 - val_switch_loss: 0.5991 - val_pos_loss: 223.7326 - val_switch_acc: 0.6749 - val_pos_mean_squared_error: 223.7326
# Epoch 7/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 231.8635 - switch_loss: 0.6091 - pos_loss: 231.2544 - switch_acc: 0.6675 - pos_mean_squared_error: 231.2544 - val_loss: 222.2569 - val_switch_loss: 0.5974 - val_pos_loss: 221.6594 - val_switch_acc: 0.6709 - val_pos_mean_squared_error: 221.6594
# Epoch 8/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 229.5220 - switch_loss: 0.6071 - pos_loss: 228.9149 - switch_acc: 0.6686 - pos_mean_squared_error: 228.9149 - val_loss: 221.1538 - val_switch_loss: 0.5985 - val_pos_loss: 220.5553 - val_switch_acc: 0.6832 - val_pos_mean_squared_error: 220.5553
# Epoch 9/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 227.8244 - switch_loss: 0.6059 - pos_loss: 227.2185 - switch_acc: 0.6704 - pos_mean_squared_error: 227.2185 - val_loss: 220.6279 - val_switch_loss: 0.5951 - val_pos_loss: 220.0328 - val_switch_acc: 0.6666 - val_pos_mean_squared_error: 220.0328
# Epoch 10/100
# 256622/256622 [==============================] - 9s 33us/step - loss: 226.2765 - switch_loss: 0.6045 - pos_loss: 225.6720 - switch_acc: 0.6713 - pos_mean_squared_error: 225.6720 - val_loss: 218.1687 - val_switch_loss: 0.5962 - val_pos_loss: 217.5725 - val_switch_acc: 0.6683 - val_pos_mean_squared_error: 217.5725
# Epoch 11/100
# 256622/256622 [==============================] - 9s 34us/step - loss: 224.9934 - switch_loss: 0.6034 - pos_loss: 224.3900 - switch_acc: 0.6714 - pos_mean_squared_error: 224.3900 - val_loss: 216.9705 - val_switch_loss: 0.5921 - val_pos_loss: 216.3784 - val_switch_acc: 0.6758 - val_pos_mean_squared_error: 216.3784
# Epoch 12/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 224.0934 - switch_loss: 0.6013 - pos_loss: 223.4922 - switch_acc: 0.6742 - pos_mean_squared_error: 223.4922 - val_loss: 216.2790 - val_switch_loss: 0.5893 - val_pos_loss: 215.6897 - val_switch_acc: 0.6812 - val_pos_mean_squared_error: 215.6897
# Epoch 13/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 223.1698 - switch_loss: 0.5984 - pos_loss: 222.5715 - switch_acc: 0.6772 - pos_mean_squared_error: 222.5715 - val_loss: 217.0918 - val_switch_loss: 0.5861 - val_pos_loss: 216.5056 - val_switch_acc: 0.6874 - val_pos_mean_squared_error: 216.5056
# Epoch 14/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 222.5395 - switch_loss: 0.5955 - pos_loss: 221.9440 - switch_acc: 0.6800 - pos_mean_squared_error: 221.9440 - val_loss: 215.7839 - val_switch_loss: 0.5849 - val_pos_loss: 215.1990 - val_switch_acc: 0.6811 - val_pos_mean_squared_error: 215.1990
# Epoch 15/100
# 256622/256622 [==============================] - 8s 32us/step - loss: 221.8794 - switch_loss: 0.5910 - pos_loss: 221.2883 - switch_acc: 0.6852 - pos_mean_squared_error: 221.2883 - val_loss: 214.6847 - val_switch_loss: 0.5727 - val_pos_loss: 214.1121 - val_switch_acc: 0.6973 - val_pos_mean_squared_error: 214.1121
# Epoch 16/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 220.8804 - switch_loss: 0.5769 - pos_loss: 220.3035 - switch_acc: 0.7014 - pos_mean_squared_error: 220.3035 - val_loss: 214.3697 - val_switch_loss: 0.5521 - val_pos_loss: 213.8176 - val_switch_acc: 0.7289 - val_pos_mean_squared_error: 213.8176
# Epoch 17/100
# 256622/256622 [==============================] - 8s 32us/step - loss: 220.3926 - switch_loss: 0.5705 - pos_loss: 219.8221 - switch_acc: 0.7092 - pos_mean_squared_error: 219.8221 - val_loss: 213.4914 - val_switch_loss: 0.5520 - val_pos_loss: 212.9395 - val_switch_acc: 0.7330 - val_pos_mean_squared_error: 212.9395
# Epoch 18/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 220.1352 - switch_loss: 0.5693 - pos_loss: 219.5659 - switch_acc: 0.7090 - pos_mean_squared_error: 219.5659 - val_loss: 213.1157 - val_switch_loss: 0.5482 - val_pos_loss: 212.5675 - val_switch_acc: 0.7164 - val_pos_mean_squared_error: 212.5675
# Epoch 19/100
# 256622/256622 [==============================] - 8s 32us/step - loss: 218.9249 - switch_loss: 0.5646 - pos_loss: 218.3603 - switch_acc: 0.7134 - pos_mean_squared_error: 218.3603 - val_loss: 214.3040 - val_switch_loss: 0.5461 - val_pos_loss: 213.7579 - val_switch_acc: 0.7265 - val_pos_mean_squared_error: 213.7579
# Epoch 20/100
# 256622/256622 [==============================] - 9s 34us/step - loss: 218.6219 - switch_loss: 0.5635 - pos_loss: 218.0584 - switch_acc: 0.7155 - pos_mean_squared_error: 218.0584 - val_loss: 212.5733 - val_switch_loss: 0.5425 - val_pos_loss: 212.0308 - val_switch_acc: 0.7451 - val_pos_mean_squared_error: 212.0308
# Epoch 21/100
# 256622/256622 [==============================] - 9s 33us/step - loss: 218.0278 - switch_loss: 0.5618 - pos_loss: 217.4660 - switch_acc: 0.7170 - pos_mean_squared_error: 217.4660 - val_loss: 212.5417 - val_switch_loss: 0.5361 - val_pos_loss: 212.0056 - val_switch_acc: 0.7448 - val_pos_mean_squared_error: 212.0056
# Epoch 22/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 217.5938 - switch_loss: 0.5598 - pos_loss: 217.0340 - switch_acc: 0.7192 - pos_mean_squared_error: 217.0340 - val_loss: 211.9302 - val_switch_loss: 0.5381 - val_pos_loss: 211.3921 - val_switch_acc: 0.7458 - val_pos_mean_squared_error: 211.3921
# Epoch 23/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 217.3606 - switch_loss: 0.5578 - pos_loss: 216.8027 - switch_acc: 0.7209 - pos_mean_squared_error: 216.8027 - val_loss: 212.3903 - val_switch_loss: 0.5388 - val_pos_loss: 211.8514 - val_switch_acc: 0.7406 - val_pos_mean_squared_error: 211.8514
# Epoch 24/100
# 256622/256622 [==============================] - 8s 31us/step - loss: 216.7887 - switch_loss: 0.5587 - pos_loss: 216.2300 - switch_acc: 0.7201 - pos_mean_squared_error: 216.2300 - val_loss: 212.0967 - val_switch_loss: 0.5389 - val_pos_loss: 211.5578 - val_switch_acc: 0.7391 - val_pos_mean_squared_error: 211.5578
# Saved model to disk
# MODEL: 3
# Train on 256633 samples, validate on 64157 samples
# Epoch 1/100
# 256633/256633 [==============================] - 9s 37us/step - loss: 706.2475 - switch_loss: 0.7822 - pos_loss: 705.4653 - switch_acc: 0.5789 - pos_mean_squared_error: 705.4653 - val_loss: 264.9052 - val_switch_loss: 0.6420 - val_pos_loss: 264.2633 - val_switch_acc: 0.6389 - val_pos_mean_squared_error: 264.2633
# Epoch 2/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 266.4469 - switch_loss: 0.6403 - pos_loss: 265.8065 - switch_acc: 0.6447 - pos_mean_squared_error: 265.8065 - val_loss: 247.7377 - val_switch_loss: 0.6132 - val_pos_loss: 247.1245 - val_switch_acc: 0.6690 - val_pos_mean_squared_error: 247.1245
# Epoch 3/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 253.8061 - switch_loss: 0.6224 - pos_loss: 253.1837 - switch_acc: 0.6597 - pos_mean_squared_error: 253.1837 - val_loss: 239.2099 - val_switch_loss: 0.6132 - val_pos_loss: 238.5967 - val_switch_acc: 0.6661 - val_pos_mean_squared_error: 238.5967
# Epoch 4/100
# 256633/256633 [==============================] - 8s 32us/step - loss: 245.4980 - switch_loss: 0.6196 - pos_loss: 244.8784 - switch_acc: 0.6639 - pos_mean_squared_error: 244.8784 - val_loss: 234.0329 - val_switch_loss: 0.6109 - val_pos_loss: 233.4220 - val_switch_acc: 0.6747 - val_pos_mean_squared_error: 233.4220
# Epoch 5/100
# 256633/256633 [==============================] - 8s 33us/step - loss: 239.9055 - switch_loss: 0.6163 - pos_loss: 239.2892 - switch_acc: 0.6654 - pos_mean_squared_error: 239.2892 - val_loss: 227.5611 - val_switch_loss: 0.6041 - val_pos_loss: 226.9570 - val_switch_acc: 0.6678 - val_pos_mean_squared_error: 226.9570
# Epoch 6/100
# 256633/256633 [==============================] - 9s 34us/step - loss: 235.9679 - switch_loss: 0.6124 - pos_loss: 235.3555 - switch_acc: 0.6667 - pos_mean_squared_error: 235.3555 - val_loss: 224.4918 - val_switch_loss: 0.6032 - val_pos_loss: 223.8886 - val_switch_acc: 0.6698 - val_pos_mean_squared_error: 223.8886
# Epoch 7/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 233.0243 - switch_loss: 0.6092 - pos_loss: 232.4151 - switch_acc: 0.6683 - pos_mean_squared_error: 232.4151 - val_loss: 223.8499 - val_switch_loss: 0.5952 - val_pos_loss: 223.2547 - val_switch_acc: 0.6843 - val_pos_mean_squared_error: 223.2547
# Epoch 8/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 230.8604 - switch_loss: 0.6066 - pos_loss: 230.2538 - switch_acc: 0.6712 - pos_mean_squared_error: 230.2538 - val_loss: 221.0312 - val_switch_loss: 0.5930 - val_pos_loss: 220.4382 - val_switch_acc: 0.6862 - val_pos_mean_squared_error: 220.4382
# Epoch 9/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 229.1925 - switch_loss: 0.6069 - pos_loss: 228.5855 - switch_acc: 0.6724 - pos_mean_squared_error: 228.5855 - val_loss: 219.7277 - val_switch_loss: 0.5926 - val_pos_loss: 219.1351 - val_switch_acc: 0.6833 - val_pos_mean_squared_error: 219.1351
# Epoch 10/100
# 256633/256633 [==============================] - 8s 32us/step - loss: 227.3563 - switch_loss: 0.6064 - pos_loss: 226.7498 - switch_acc: 0.6735 - pos_mean_squared_error: 226.7498 - val_loss: 217.9591 - val_switch_loss: 0.5965 - val_pos_loss: 217.3626 - val_switch_acc: 0.6935 - val_pos_mean_squared_error: 217.3626
# Epoch 11/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 225.8415 - switch_loss: 0.6044 - pos_loss: 225.2371 - switch_acc: 0.6767 - pos_mean_squared_error: 225.2371 - val_loss: 216.5508 - val_switch_loss: 0.5917 - val_pos_loss: 215.9592 - val_switch_acc: 0.6763 - val_pos_mean_squared_error: 215.9592
# Epoch 12/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 224.6307 - switch_loss: 0.6030 - pos_loss: 224.0277 - switch_acc: 0.6775 - pos_mean_squared_error: 224.0277 - val_loss: 215.5216 - val_switch_loss: 0.5890 - val_pos_loss: 214.9326 - val_switch_acc: 0.6937 - val_pos_mean_squared_error: 214.9326
# Epoch 13/100
# 256633/256633 [==============================] - 9s 34us/step - loss: 223.2554 - switch_loss: 0.6004 - pos_loss: 222.6549 - switch_acc: 0.6802 - pos_mean_squared_error: 222.6549 - val_loss: 214.8351 - val_switch_loss: 0.5855 - val_pos_loss: 214.2496 - val_switch_acc: 0.6876 - val_pos_mean_squared_error: 214.2496
# Epoch 14/100
# 256633/256633 [==============================] - 9s 34us/step - loss: 222.2813 - switch_loss: 0.5974 - pos_loss: 221.6838 - switch_acc: 0.6831 - pos_mean_squared_error: 221.6838 - val_loss: 214.5577 - val_switch_loss: 0.5816 - val_pos_loss: 213.9760 - val_switch_acc: 0.7067 - val_pos_mean_squared_error: 213.9760
# Epoch 15/100
# 256633/256633 [==============================] - 9s 34us/step - loss: 221.8417 - switch_loss: 0.5941 - pos_loss: 221.2476 - switch_acc: 0.6881 - pos_mean_squared_error: 221.2476 - val_loss: 213.7972 - val_switch_loss: 0.5780 - val_pos_loss: 213.2192 - val_switch_acc: 0.6911 - val_pos_mean_squared_error: 213.2192
# Epoch 16/100
# 256633/256633 [==============================] - 8s 33us/step - loss: 220.7715 - switch_loss: 0.5887 - pos_loss: 220.1829 - switch_acc: 0.6940 - pos_mean_squared_error: 220.1829 - val_loss: 212.9431 - val_switch_loss: 0.5695 - val_pos_loss: 212.3735 - val_switch_acc: 0.7076 - val_pos_mean_squared_error: 212.3735
# Epoch 17/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 220.1263 - switch_loss: 0.5836 - pos_loss: 219.5427 - switch_acc: 0.6995 - pos_mean_squared_error: 219.5427 - val_loss: 214.5549 - val_switch_loss: 0.5653 - val_pos_loss: 213.9896 - val_switch_acc: 0.7100 - val_pos_mean_squared_error: 213.9896
# Epoch 18/100
# 256633/256633 [==============================] - 8s 31us/step - loss: 219.6132 - switch_loss: 0.5794 - pos_loss: 219.0338 - switch_acc: 0.7030 - pos_mean_squared_error: 219.0338 - val_loss: 213.9366 - val_switch_loss: 0.5603 - val_pos_loss: 213.3763 - val_switch_acc: 0.7273 - val_pos_mean_squared_error: 213.3763
# Saved model to disk
# MODEL: 4
# Train on 256642 samples, validate on 64148 samples
# Epoch 1/100
# 256642/256642 [==============================] - 9s 36us/step - loss: 723.2297 - switch_loss: 0.8086 - pos_loss: 722.4211 - switch_acc: 0.5717 - pos_mean_squared_error: 722.4211 - val_loss: 263.9570 - val_switch_loss: 0.6353 - val_pos_loss: 263.3218 - val_switch_acc: 0.6404 - val_pos_mean_squared_error: 263.3218
# Epoch 2/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 265.3141 - switch_loss: 0.6450 - pos_loss: 264.6691 - switch_acc: 0.6425 - pos_mean_squared_error: 264.6691 - val_loss: 248.9677 - val_switch_loss: 0.6132 - val_pos_loss: 248.3545 - val_switch_acc: 0.6591 - val_pos_mean_squared_error: 248.3545
# Epoch 3/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 253.1867 - switch_loss: 0.6189 - pos_loss: 252.5678 - switch_acc: 0.6643 - pos_mean_squared_error: 252.5678 - val_loss: 241.1158 - val_switch_loss: 0.6047 - val_pos_loss: 240.5111 - val_switch_acc: 0.6789 - val_pos_mean_squared_error: 240.5111
# Epoch 4/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 245.7242 - switch_loss: 0.6137 - pos_loss: 245.1105 - switch_acc: 0.6677 - pos_mean_squared_error: 245.1105 - val_loss: 235.7306 - val_switch_loss: 0.6044 - val_pos_loss: 235.1262 - val_switch_acc: 0.6755 - val_pos_mean_squared_error: 235.1262
# Epoch 5/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 241.0975 - switch_loss: 0.6112 - pos_loss: 240.4863 - switch_acc: 0.6700 - pos_mean_squared_error: 240.4863 - val_loss: 232.8500 - val_switch_loss: 0.5996 - val_pos_loss: 232.2505 - val_switch_acc: 0.6798 - val_pos_mean_squared_error: 232.2505
# Epoch 6/100
# 256642/256642 [==============================] - 8s 32us/step - loss: 237.4496 - switch_loss: 0.6083 - pos_loss: 236.8413 - switch_acc: 0.6735 - pos_mean_squared_error: 236.8413 - val_loss: 229.1165 - val_switch_loss: 0.5973 - val_pos_loss: 228.5192 - val_switch_acc: 0.6828 - val_pos_mean_squared_error: 228.5192
# Epoch 7/100
# 256642/256642 [==============================] - 9s 35us/step - loss: 234.6049 - switch_loss: 0.6034 - pos_loss: 234.0015 - switch_acc: 0.6779 - pos_mean_squared_error: 234.0015 - val_loss: 227.0576 - val_switch_loss: 0.5922 - val_pos_loss: 226.4654 - val_switch_acc: 0.6789 - val_pos_mean_squared_error: 226.4654
# Epoch 8/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 232.1045 - switch_loss: 0.5975 - pos_loss: 231.5070 - switch_acc: 0.6822 - pos_mean_squared_error: 231.5070 - val_loss: 225.3303 - val_switch_loss: 0.5865 - val_pos_loss: 224.7438 - val_switch_acc: 0.6921 - val_pos_mean_squared_error: 224.7438
# Epoch 9/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 229.8337 - switch_loss: 0.5951 - pos_loss: 229.2386 - switch_acc: 0.6844 - pos_mean_squared_error: 229.2386 - val_loss: 223.0637 - val_switch_loss: 0.5830 - val_pos_loss: 222.4808 - val_switch_acc: 0.6956 - val_pos_mean_squared_error: 222.4808
# Epoch 10/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 228.2202 - switch_loss: 0.5927 - pos_loss: 227.6274 - switch_acc: 0.6887 - pos_mean_squared_error: 227.6274 - val_loss: 222.3445 - val_switch_loss: 0.5802 - val_pos_loss: 221.7643 - val_switch_acc: 0.6959 - val_pos_mean_squared_error: 221.7643
# Epoch 11/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 227.0147 - switch_loss: 0.5898 - pos_loss: 226.4249 - switch_acc: 0.6906 - pos_mean_squared_error: 226.4249 - val_loss: 221.4700 - val_switch_loss: 0.5760 - val_pos_loss: 220.8941 - val_switch_acc: 0.7056 - val_pos_mean_squared_error: 220.8941
# Epoch 12/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 226.0754 - switch_loss: 0.5865 - pos_loss: 225.4889 - switch_acc: 0.6955 - pos_mean_squared_error: 225.4889 - val_loss: 220.0841 - val_switch_loss: 0.5786 - val_pos_loss: 219.5055 - val_switch_acc: 0.6935 - val_pos_mean_squared_error: 219.5055
# Epoch 13/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 224.8168 - switch_loss: 0.5829 - pos_loss: 224.2338 - switch_acc: 0.6998 - pos_mean_squared_error: 224.2338 - val_loss: 219.5650 - val_switch_loss: 0.5715 - val_pos_loss: 218.9936 - val_switch_acc: 0.7147 - val_pos_mean_squared_error: 218.9936
# Epoch 14/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 223.9034 - switch_loss: 0.5806 - pos_loss: 223.3228 - switch_acc: 0.7034 - pos_mean_squared_error: 223.3228 - val_loss: 220.1571 - val_switch_loss: 0.5645 - val_pos_loss: 219.5926 - val_switch_acc: 0.7168 - val_pos_mean_squared_error: 219.5926
# Epoch 15/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 223.2160 - switch_loss: 0.5774 - pos_loss: 222.6386 - switch_acc: 0.7037 - pos_mean_squared_error: 222.6386 - val_loss: 218.7067 - val_switch_loss: 0.5633 - val_pos_loss: 218.1435 - val_switch_acc: 0.7148 - val_pos_mean_squared_error: 218.1435
# Epoch 16/100
# 256642/256642 [==============================] - 8s 33us/step - loss: 222.5934 - switch_loss: 0.5767 - pos_loss: 222.0167 - switch_acc: 0.7070 - pos_mean_squared_error: 222.0167 - val_loss: 217.7358 - val_switch_loss: 0.5611 - val_pos_loss: 217.1747 - val_switch_acc: 0.7241 - val_pos_mean_squared_error: 217.1747
# Epoch 17/100
# 256642/256642 [==============================] - 9s 34us/step - loss: 221.9997 - switch_loss: 0.5734 - pos_loss: 221.4263 - switch_acc: 0.7094 - pos_mean_squared_error: 221.4263 - val_loss: 217.0447 - val_switch_loss: 0.5565 - val_pos_loss: 216.4882 - val_switch_acc: 0.7273 - val_pos_mean_squared_error: 216.4882
# Epoch 18/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 220.9741 - switch_loss: 0.5718 - pos_loss: 220.4022 - switch_acc: 0.7118 - pos_mean_squared_error: 220.4022 - val_loss: 216.7833 - val_switch_loss: 0.5551 - val_pos_loss: 216.2282 - val_switch_acc: 0.7303 - val_pos_mean_squared_error: 216.2282
# Epoch 19/100
# 256642/256642 [==============================] - 9s 34us/step - loss: 220.5803 - switch_loss: 0.5664 - pos_loss: 220.0139 - switch_acc: 0.7188 - pos_mean_squared_error: 220.0139 - val_loss: 215.7954 - val_switch_loss: 0.5489 - val_pos_loss: 215.2465 - val_switch_acc: 0.7367 - val_pos_mean_squared_error: 215.2465
# Epoch 20/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 220.0282 - switch_loss: 0.5607 - pos_loss: 219.4675 - switch_acc: 0.7251 - pos_mean_squared_error: 219.4675 - val_loss: 216.7219 - val_switch_loss: 0.5432 - val_pos_loss: 216.1788 - val_switch_acc: 0.7448 - val_pos_mean_squared_error: 216.1788
# Epoch 21/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 219.5165 - switch_loss: 0.5567 - pos_loss: 218.9598 - switch_acc: 0.7295 - pos_mean_squared_error: 218.9598 - val_loss: 215.0253 - val_switch_loss: 0.5419 - val_pos_loss: 214.4834 - val_switch_acc: 0.7449 - val_pos_mean_squared_error: 214.4834
# Epoch 22/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 218.8447 - switch_loss: 0.5545 - pos_loss: 218.2902 - switch_acc: 0.7322 - pos_mean_squared_error: 218.2902 - val_loss: 215.4939 - val_switch_loss: 0.5400 - val_pos_loss: 214.9540 - val_switch_acc: 0.7383 - val_pos_mean_squared_error: 214.9540
# Epoch 23/100
# 256642/256642 [==============================] - 8s 31us/step - loss: 218.6329 - switch_loss: 0.5514 - pos_loss: 218.0815 - switch_acc: 0.7338 - pos_mean_squared_error: 218.0815 - val_loss: 216.0135 - val_switch_loss: 0.5411 - val_pos_loss: 215.4724 - val_switch_acc: 0.7338 - val_pos_mean_squared_error: 215.4724
# Saved model to disk
# MODEL: 5
# Train on 256649 samples, validate on 64141 samples
# Epoch 1/100
# 256649/256649 [==============================] - 9s 35us/step - loss: 657.1656 - switch_loss: 0.7783 - pos_loss: 656.3873 - switch_acc: 0.5791 - pos_mean_squared_error: 656.3873 - val_loss: 264.0288 - val_switch_loss: 0.6278 - val_pos_loss: 263.4010 - val_switch_acc: 0.6489 - val_pos_mean_squared_error: 263.4010
# Epoch 2/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 263.2866 - switch_loss: 0.6333 - pos_loss: 262.6534 - switch_acc: 0.6515 - pos_mean_squared_error: 262.6534 - val_loss: 247.7964 - val_switch_loss: 0.6083 - val_pos_loss: 247.1881 - val_switch_acc: 0.6718 - val_pos_mean_squared_error: 247.1881
# Epoch 3/100
# 256649/256649 [==============================] - 9s 35us/step - loss: 252.0968 - switch_loss: 0.6163 - pos_loss: 251.4805 - switch_acc: 0.6642 - pos_mean_squared_error: 251.4805 - val_loss: 239.8866 - val_switch_loss: 0.6048 - val_pos_loss: 239.2819 - val_switch_acc: 0.6789 - val_pos_mean_squared_error: 239.2819
# Epoch 4/100
# 256649/256649 [==============================] - 8s 32us/step - loss: 244.6150 - switch_loss: 0.6118 - pos_loss: 244.0033 - switch_acc: 0.6651 - pos_mean_squared_error: 244.0033 - val_loss: 235.3637 - val_switch_loss: 0.6018 - val_pos_loss: 234.7619 - val_switch_acc: 0.6696 - val_pos_mean_squared_error: 234.7619
# Epoch 5/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 239.3356 - switch_loss: 0.6103 - pos_loss: 238.7253 - switch_acc: 0.6657 - pos_mean_squared_error: 238.7253 - val_loss: 230.3144 - val_switch_loss: 0.6050 - val_pos_loss: 229.7095 - val_switch_acc: 0.6779 - val_pos_mean_squared_error: 229.7095
# Epoch 6/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 235.4728 - switch_loss: 0.6090 - pos_loss: 234.8638 - switch_acc: 0.6661 - pos_mean_squared_error: 234.8638 - val_loss: 228.3360 - val_switch_loss: 0.5981 - val_pos_loss: 227.7379 - val_switch_acc: 0.6727 - val_pos_mean_squared_error: 227.7379
# Epoch 7/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 232.3852 - switch_loss: 0.6038 - pos_loss: 231.7813 - switch_acc: 0.6717 - pos_mean_squared_error: 231.7813 - val_loss: 225.7498 - val_switch_loss: 0.5935 - val_pos_loss: 225.1564 - val_switch_acc: 0.6802 - val_pos_mean_squared_error: 225.1564
# Epoch 8/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 230.2572 - switch_loss: 0.6009 - pos_loss: 229.6564 - switch_acc: 0.6762 - pos_mean_squared_error: 229.6564 - val_loss: 224.7322 - val_switch_loss: 0.5885 - val_pos_loss: 224.1437 - val_switch_acc: 0.6922 - val_pos_mean_squared_error: 224.1437
# Epoch 9/100
# 256649/256649 [==============================] - 9s 33us/step - loss: 228.2257 - switch_loss: 0.5989 - pos_loss: 227.6267 - switch_acc: 0.6778 - pos_mean_squared_error: 227.6267 - val_loss: 222.2633 - val_switch_loss: 0.5869 - val_pos_loss: 221.6765 - val_switch_acc: 0.6964 - val_pos_mean_squared_error: 221.6765
# Epoch 10/100
# 256649/256649 [==============================] - 9s 34us/step - loss: 227.1111 - switch_loss: 0.5989 - pos_loss: 226.5122 - switch_acc: 0.6799 - pos_mean_squared_error: 226.5122 - val_loss: 221.4419 - val_switch_loss: 0.5853 - val_pos_loss: 220.8566 - val_switch_acc: 0.6983 - val_pos_mean_squared_error: 220.8566
# Epoch 11/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 226.1055 - switch_loss: 0.5975 - pos_loss: 225.5080 - switch_acc: 0.6811 - pos_mean_squared_error: 225.5080 - val_loss: 220.1236 - val_switch_loss: 0.5845 - val_pos_loss: 219.5391 - val_switch_acc: 0.6960 - val_pos_mean_squared_error: 219.5391
# Epoch 12/100
# 256649/256649 [==============================] - 8s 32us/step - loss: 225.0963 - switch_loss: 0.5968 - pos_loss: 224.4995 - switch_acc: 0.6819 - pos_mean_squared_error: 224.4995 - val_loss: 219.6180 - val_switch_loss: 0.5838 - val_pos_loss: 219.0342 - val_switch_acc: 0.6991 - val_pos_mean_squared_error: 219.0342
# Epoch 13/100
# 256649/256649 [==============================] - 9s 35us/step - loss: 224.3159 - switch_loss: 0.5930 - pos_loss: 223.7229 - switch_acc: 0.6866 - pos_mean_squared_error: 223.7229 - val_loss: 218.7447 - val_switch_loss: 0.5788 - val_pos_loss: 218.1659 - val_switch_acc: 0.7071 - val_pos_mean_squared_error: 218.1659
# Epoch 14/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 223.2906 - switch_loss: 0.5886 - pos_loss: 222.7020 - switch_acc: 0.6922 - pos_mean_squared_error: 222.7020 - val_loss: 218.3357 - val_switch_loss: 0.5714 - val_pos_loss: 217.7643 - val_switch_acc: 0.7180 - val_pos_mean_squared_error: 217.7643
# Epoch 15/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 222.2851 - switch_loss: 0.5839 - pos_loss: 221.7012 - switch_acc: 0.6991 - pos_mean_squared_error: 221.7012 - val_loss: 217.7771 - val_switch_loss: 0.5655 - val_pos_loss: 217.2116 - val_switch_acc: 0.7189 - val_pos_mean_squared_error: 217.2116
# Epoch 16/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 221.6351 - switch_loss: 0.5800 - pos_loss: 221.0552 - switch_acc: 0.7050 - pos_mean_squared_error: 221.0552 - val_loss: 216.8899 - val_switch_loss: 0.5617 - val_pos_loss: 216.3283 - val_switch_acc: 0.7239 - val_pos_mean_squared_error: 216.3283
# Epoch 17/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 221.4220 - switch_loss: 0.5745 - pos_loss: 220.8475 - switch_acc: 0.7126 - pos_mean_squared_error: 220.8475 - val_loss: 216.3364 - val_switch_loss: 0.5543 - val_pos_loss: 215.7821 - val_switch_acc: 0.7346 - val_pos_mean_squared_error: 215.7821
# Epoch 18/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 220.5804 - switch_loss: 0.5689 - pos_loss: 220.0116 - switch_acc: 0.7181 - pos_mean_squared_error: 220.0116 - val_loss: 216.7967 - val_switch_loss: 0.5478 - val_pos_loss: 216.2489 - val_switch_acc: 0.7430 - val_pos_mean_squared_error: 216.2489
# Epoch 19/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 219.9874 - switch_loss: 0.5653 - pos_loss: 219.4221 - switch_acc: 0.7215 - pos_mean_squared_error: 219.4221 - val_loss: 215.6987 - val_switch_loss: 0.5449 - val_pos_loss: 215.1538 - val_switch_acc: 0.7454 - val_pos_mean_squared_error: 215.1538
# Epoch 20/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 219.4356 - switch_loss: 0.5608 - pos_loss: 218.8748 - switch_acc: 0.7245 - pos_mean_squared_error: 218.8748 - val_loss: 215.7054 - val_switch_loss: 0.5382 - val_pos_loss: 215.1672 - val_switch_acc: 0.7505 - val_pos_mean_squared_error: 215.1672
# Epoch 21/100
# 256649/256649 [==============================] - 8s 31us/step - loss: 218.9070 - switch_loss: 0.5583 - pos_loss: 218.3487 - switch_acc: 0.7276 - pos_mean_squared_error: 218.3487 - val_loss: 216.1380 - val_switch_loss: 0.5376 - val_pos_loss: 215.6004 - val_switch_acc: 0.7539 - val_pos_mean_squared_error: 215.6004
# Saved model to disk
